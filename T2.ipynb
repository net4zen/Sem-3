# %%
x = input("Enter the string: ")
# if x.endswith("ing"):
n =len(x)
if n>=3:
    if x[n-3:n]=="ing":
        print(x+"ly")
    else:
        print( x +"ing")
else:
    print("noooo")

# %%
str = "32.054,23"
# dot = str.split(".")
# com =dot[1].split(",")
# print(dot[0]+","+com[0]+"."+com[1])

b

# %%
str1 = input("Enter String-1: ")
str2 = input("Enter String-2: ")

for i,j in str1:

# %% [markdown]
# ### WAP to sort a list according to its second element value in its sublist
# #### eg [['a',32],['b',34]]

# %%
# l = eval(input("Enter the list:")
l
nl = []
al = []
print(l)
for i in l {
    if i.isnumeric():
}

# %% [markdown]
# ```python
# The Syracuse (also called Collatz or Hailstone) sequence is generated by starting with a natural number and repeatedly
# applying the following function until reaching 1:
#  syr(x) = 1/2 if x is even; and
# syr(x) = 3x + 1 if x is odd
# For example, the Syracuse sequence starting with 5 is: 5, 16, 8, 4, 2, 1.
# Use of inbuilt function or math library is not allowed.
#  This sequence will always go to 1 for every possible starting value.
#  Write a program that
#  1.Gets a star ng value from the user
#  2.Prints the Syracuse sequence for that star ng value.
# ```

# %% [markdown]
# ### Q495 Write a Python program to demonstrate the negative index in a Tuple

# %%
t = (2,3,4,1,10)
t[-1]
# Out:
# 10

# %%
help
(ord)
# Out:
# <function ord(c, /)>

# %%
help(ord)
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
s = 'THis is a python programming tutorial'
dir(s
   )
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# ### Q496  Write a program to remove I'th character from string in python.

# %% [markdown]
# ### Q498 Write a program to find all occuences of a sub string in a given string by ignoring the case.

# %%
s = input("Enter the string:")
sub = 'ok'
l =s.split(sub)
occ = len(l)-1 
print(occ)
# Out:
# Enter the string: okmdocdokdcmocdpckodkmcodcndockdcdmdckdcpokdcdokcdcd
# 4

# %%
a=input("Enter digits: ")
sum = 0
avg=0
digi=0
for i in a:
    if i.isnumeric():
        sum+=int(i)
        digi+=1
print(sum,sum/digi)
# Out:
# Enter digits:  1,2,3,4
# 10 2

# %%
s ="Write a Python program to print even length words in a string"
l = s.split()
for i in l:
    if len(i)%2==0:
        print(i)
# Out:
# Python
# to
# even
# length
# in
# string

# %% [markdown]
# ### Q.310
# ```
# Write a Python program using function to shift the decimal digits n places to the left, wrapping the extra digits around. If
# shift > the number of digits of n, then reverse the string.
#  Note:
# Function will take two parameters:
# 1. The number
# 2. How much shift user want

# %%
def shifting(number,shift):
    strnumber = str(number)
    digits = len(strnumber)
    
    if shift > digits:
        result = strnumber[::-1]
    else:
        result = strnumber[shift:] + strnumber[:shift]
    
    return int(result)

# %%
shifting(12345,6)
# Out:
# 54321

# %%
s1 = "eclhol"
s2 = "ollelh"
bal = False
if len(s1)==len(s2):
    for i in s1:
        for j in s2:
            if i == j:
                continue
            
    bal = True

if bal:
    print('Balanced')
else:
    print('not balanced')
# Out:
# not balanced
# Balanced

# %%
#Write a Python program to print the even numbers from a given list.

l = eval(input("Enter the list: "))
l[0],l[-1]=l[-1],l[0]

print(l)
# Out:
# Enter the list:  [1,2,3,4,5]
# [5, 2, 3, 4, 1]

# %%
l =  eval(input("Enter the list: "))
print(l[::-1])
# Out:
# Enter the list:  [1,2,3,4,5]
# [5, 4, 3, 2, 1]

# %%
dict1 = {1:'a',2:'b'}
dic2={3:'c',4:'d'}
dict1.update(dic2)
print(dict1)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
#Write a Python program to rearrange positive and negative numbers in a given array using Lambda.

l = eval(input("Enter the list:"))
pos = list(filter(lambda x: x>=0,l))
neg = list(filter(lambda x: x<=0,l))
print(pos+neg)
# Out:
# Enter the list: 1,-1,-2,-4,-5,1,2,3,4,3,-5
# [1, 1, 2, 3, 4, 3, -1, -2, -4, -5, -5]
